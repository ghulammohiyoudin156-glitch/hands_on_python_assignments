# %% [markdown]
# # Assignment 02 - Dictionaries & Sets
# ### Data Analytics in Python | Week 2, Class 4
#
# This assignment has **three phases** and **30 questions**.
#
# **Phase 1 (Q1-Q10):** Standalone practice - dictionaries and sets, no dataset provided.
# Write your own data or use what the question gives you.
#
# **Phase 2 (Q11-Q20):** Analysis of an **e-commerce product catalog** stored as a
# dictionary of nested dictionaries - the structure you would get back from a
# real product database or a REST API like Shopify or WooCommerce.
#
# **Phase 3 (Q21-Q30):** Analysis of a **university student registry** stored as a
# dictionary where each student record contains nested lists - enrolments,
# grades, skills - the kind of schema you find in any student information system.
#
# > Run the notebook top to bottom (`Kernel -> Restart & Run All`) before submitting.
# > Every code cell must execute without errors.

# %% [markdown]
# ## Phase 1 - Dictionaries & Sets Fundamentals `[30 marks | 3 marks each]`
#
# No dataset is provided here. Each question either gives you the data inline
# or asks you to create it yourself.

# %% [markdown]
# ### Q1 - Build a lookup dict from two parallel lists `[3 marks]`
#
# You are given two parallel lists: `cities` and `populations` (in millions).
# Build a dictionary `city_pop` that maps each city to its population.
#
# Then:
# - Print the full dictionary
# - Look up Lahore's population using `.get()`
# - Look up a city that does **not** exist (`"Quetta"`) using `.get()` with
#   the default string `"not in database"`
#
# ```
# cities      = ["Karachi", "Lahore", "Islamabad", "Faisalabad", "Rawalpindi"]
# populations = [16.1, 13.1, 1.2, 3.6, 2.3]
# ```
#
# *Hint: `dict(zip(....))` pairs elements by position.*

# %%
cities      = ["Karachi", "Lahore", "Islamabad", "Faisalabad", "Rawalpindi"]
populations = [16.1, 13.1, 1.2, 3.6, 2.3]

cities_populations = dict(zip(cities, populations))
print(cities_populations)
# Out:
# {'Karachi': 16.1, 'Lahore': 13.1, 'Islamabad': 1.2, 'Faisalabad': 3.6, 'Rawalpindi': 2.3}

# %% [markdown]
# ### Q2 - Mutate a dictionary: add, update, and remove `[3 marks]`
#
# Start with this patient dictionary:
# ```python
# patient = {"id": "P0042", "name": "Ahmad Raza", "age": 34, "temp": 38.7}
# ```
#
# Perform these four operations **in order**, printing the dictionary after each:
# 1. Add a new key `"blood_group"` with value `"A+"`
# 2. Update `"age"` to `35`
# 3. Use `.setdefault()` to add `"status": "admitted"` - then call
#    `.setdefault("age", 99)` and explain in a comment why `"age"` does **not** become 99
# 4. Remove `"temp"` using `.pop()` and store the removed value - print it

# %%
patient = {"id": "P0042", "name": "Ahmad Raza", "age": 34, "temp": 38.7}

# 1. Add blood_group
patient['blood_group'] = 'b-' 
print(patient)
# 2. Udate age
patient['age'] = 56
print(patient)
# 3. setdefault
patient.setdefault('weight', 70)
print(patient)

# 4. pop temp
patient.pop('temp')
print(patient)
# Out:
# {'id': 'P0042', 'name': 'Ahmad Raza', 'age': 34, 'temp': 38.7, 'blood_group': 'b-'}
# {'id': 'P0042', 'name': 'Ahmad Raza', 'age': 56, 'temp': 38.7, 'blood_group': 'b-'}
# {'id': 'P0042', 'name': 'Ahmad Raza', 'age': 56, 'temp': 38.7, 'blood_group': 'b-', 'weight': 70}
# {'id': 'P0042', 'name': 'Ahmad Raza', 'age': 56, 'blood_group': 'b-', 'weight': 70}

# %% [markdown]
# ### Q3 - Merge two dictionaries `[3 marks]`
#
# A lab report arrives in two separate dicts. Merge them into one.
#
# ```python
# basic_panel  = {"WBC": 8.2, "RBC": 4.9, "Hb": 13.5, "Plt": 250}
# chem_panel   = {"Na": 142, "K": 4.1, "Cr": 0.9, "Glucose": 6.2}
# ```
#
# 1. Merge `chem_panel` into `basic_panel`
# 2. Print the merged result
# 3. Now suppose `Glucose` needs to be updated to `7.8` because the
#    first reading was wrong. Update it and print the corrected dict
# 4. Print all the keys and all the values on separate lines.

# %%
basic_panel = {"WBC": 8.2, "RBC": 4.9, "Hb": 13.5, "Plt": 250}
chem_panel  = {"Na": 142, "K": 4.1, "Cr": 0.9, "glucose": 6.2}

basic_panel.update(chem_panel)
print(basic_panel)

basic_panel ['glucose']=7.8
print(basic_panel)
for key in basic_panel.keys():
 print(key)
# Out:
# {'WBC': 8.2, 'RBC': 4.9, 'Hb': 13.5, 'Plt': 250, 'Na': 142, 'K': 4.1, 'Cr': 0.9, 'glucose': 6.2}
# {'WBC': 8.2, 'RBC': 4.9, 'Hb': 13.5, 'Plt': 250, 'Na': 142, 'K': 4.1, 'Cr': 0.9, 'glucose': 7.8}

# %% [markdown]
# ### Q4 - Dictionary comprehension: transform and filter `[3 marks]`
#
# You have a dict of student scores:
# ```python
# scores = {"Ahmad": 88, "Sara": 42, "Bilal": 76, "Zara": 55,
#           "Hassan": 91, "Nida": 38, "Usman": 63}
# ```
#
# Using **dict comprehensions** (one comprehension per task):
# 1. Build `grade_dict` that maps each name to `"Pass"` if score >= 50,
#    else `"Fail"`
# 2. Build `high_scorers` containing only students who scored **above 75**,
#    with their scores
# 3. Build `scaled` where every score is normalised to 0-100 by dividing
#    by the max score - round to 2 decimal places
#
# Print all three dicts.

# %%
scores = {"Ahmad": 88, "Sara": 42, "Bilal": 76, "Zara": 55,
          "Hassan": 91, "Nida": 38, "Usman": 63}

# 1. grade_dict
grade_dict = {name:('pass' if score>=50 else 'fail')for name,score in scores.items()}

# 2. high_scorers
high_scorers = {name:score for name,score in scores.items() if score>=75}
# 3. scaled
max_scores = max(scores.values())
scaled = {name: round(score/max_scores*100, 2) for name,score in scores.items()}
print(grade_dict)
print(high_scorers)
print(scaled)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 10
#       6
#       7 # 2. high_scorers
#       8 high_scorers = {name:score for name,score in scores.items() if score>=75}
#       9 # 3. scaled
# ---> 10 max_scores = max(scores.values())
#      11 scaled = {name: round(score/max_scores*100, 2) for name,score in scores.items()}
#      12 print(grade_dict)
#      13 print(high_scorers)
#
# TypeError: 'int' object is not callable

# %% [markdown]
# ### Q5 - Frequency counter using dict comprehension `[3 marks]`
#
# Given this list of diagnoses from a clinic:
# ```python
# diagnoses = ["Fever", "Diabetes", "Fever", "Hypertension", "Diabetes",
#              "Fever", "Asthma", "Hypertension", "Fever", "Diabetes",
#              "Asthma", "Fever", "Hypertension", "Diabetes", "Fever"]
# ```
#
# 1. Build a frequency dictionary `freq` using a dict comprehension.
#    Use `set()` to get unique diagnoses and `.count()` to tally each.
# 2. Print each diagnosis and its count, sorted by count from **highest to lowest**.
# 3. Find and print the most common diagnosis using `max(freq, key=freq.get)`.
#
# *Hint: `sorted(freq, key=freq.get, reverse=True)` gives keys sorted by value.*

# %%
diagnoses = ["Fever", "Diabetes", "Fever", "Hypertension", "Diabetes",
             "Fever", "Asthma", "Hypertension", "Fever", "Diabetes",
             "Asthma", "Fever", "Hypertension", "Diabetes", "Fever"]

# your code here
#diagnoses = set(diagnoses)
#print(diagnoses)
freq = {diagnosis: diagnoses.count(diagnosis) for diagnosis in set(diagnoses)}
print(freq)
for diagnosis in sorted(freq.keys()):
    print(diagnosis, freq[diagnosis])
most_common = max(freq, key=freq.get)
print("most common diagnosis:", most_common)
# Out:
# {'Asthma': 2, 'Hypertension': 3, 'Diabetes': 4, 'Fever': 6}
# Asthma 2
# Diabetes 4
# Fever 6
# Hypertension 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 12
#       8 freq = {diagnosis: diagnoses.count(diagnosis) for diagnosis in set(diagnoses)}
#       9 print(freq)
#      10 for diagnosis in sorted(freq.keys()):
#      11     print(diagnosis, freq[diagnosis])
# ---> 12 most_common = max(freq, key=freq.get)
#      13 print("most common diagnosis:", most_common)
#
# TypeError: 'int' object is not callable

# %% [markdown]
# ### Q6 - Set creation and uniqueness `[3 marks]`
#
# 1. Create a set `enrolled` from this list (which has duplicates):
#    ```python
#    signups = ["Ahmad", "Sara", "Bilal", "Ahmad", "Sara", "Zara", "Ahmad"]
#    ```
#    Print the set and the count of **unique** students.
#
# 2. The following students have now paid their fees:
#    ```python
#    paid = {"Sara", "Zara", "Nida", "Hassan"}
#    ```
#    Add `"Ahmad"` to `paid`.
#    Try adding `"Sara"` again - print the set to confirm duplicates are ignored.
#
# 3. Remove `"Nida"` from `paid` using `.discard()`.
#    Try to `discard` a name that does not exist (`"Kamran"`) - confirm no error.
#    Print the final `paid` set.

# %%
signups = ["Ahmad", "Sara", "Bilal", "Ahmad", "Sara", "Zara", "Ahmad"]

# 1. Create set from list
signups_set = set(signups)
print(signups_set)

# 2. Add to pai
paid = {'ahmed','bilal'}
print(paid)

# 3. discard from paid

# %% [markdown]
# ### Q7 - Set operations: the four core operators `[3 marks]`
#
# Two departments submitted lists of required Python libraries:
#
# ```python
# data_science = {"pandas", "numpy", "scikit-learn", "matplotlib",
#                 "seaborn", "scipy"}
# web_dev      = {"flask", "django", "requests", "numpy",
#                 "sqlalchemy", "pandas"}
# ```
#
# Using **operators** (`|`, `&`, `-`, `^`) only (no method names), compute and print:
# 1. All libraries needed by **either** team
# 2. Libraries needed by **both** teams (to buy one shared license)
# 3. Libraries needed by data science **but not** web dev
# 4. Libraries that are **exclusive** to exactly one team (not shared)
#
# Label each result clearly.

# %%
data_science = {"pandas", "numpy", "scikit-learn", "matplotlib",
                "seaborn", "scipy"}
web_dev      = {"flask", "django", "requests", "numpy",
                "sqlalchemy", "pandas"}

# 1. All libraries
either_team = data_science ^ web_dev
print(either_team)
# 2. libraries in both
either_team = data_science & web_dev
print(either_team)
# 3. data_science only
data_science_only = data_science - web_dev
print(data_science_only)
# 4. Libraries not shared (Symmetric difference)
not_shared = data_science ^ web_dev
print(not_shared)
# Out:
# {'requests', 'scipy', 'scikit-learn', 'sqlalchemy', 'flask', 'django', 'seaborn', 'matplotlib'}
# {'pandas', 'numpy'}
# {'seaborn', 'scipy', 'matplotlib', 'scikit-learn'}
# {'requests', 'scipy', 'scikit-learn', 'sqlalchemy', 'flask', 'django', 'seaborn', 'matplotlib'}

# %% [markdown]
# ### Q8 - .issubset(), .issuperset(), .isdisjoint() `[3 marks]`
#
# ```python
# core_drugs     = {"Paracetamol", "Amoxicillin", "Omeprazole"}
# pharmacy_stock = {"Paracetamol", "Amoxicillin", "Omeprazole",
#                   "Metformin", "Atorvastatin", "Lisinopril"}
# banned_drugs   = {"Thalidomide", "Phenacetin", "Aminopyrine"}
# ```
#
# Answer these questions using the appropriate set methods and print
# a clear `True/False` answer with a one-line explanation for each:
#
# 1. Does the pharmacy have all the core drugs in stock?
# 2. Does the pharmacy's stock fully contain the core drug list?
# 3. Is there any overlap between `pharmacy_stock` and `banned_drugs`?
#    (This is a compliance check - no overlap is the safe answer.)

# %%
core_drugs     = {"Paracetamol", "Amoxicillin", "Omeprazole"}
pharmacy_stock = {"Paracetamol", "Amoxicillin", "Omeprazole",
                  "Metformin", "Atorvastatin", "Lisinopril"}
banned_drugs   = {"Thalidomide", "Phenacetin", "Aminopyrine"}

# 1. Does the pharmacy have all the core drugs in stock?
has_all_core_drugs = core_drugs.issubset(pharmacy_stock)
print(has_all_core_drugs)
# 2. Does the pharmacy's stock fully contain the core drug list?
has_all_core_drugs = core_drugs.isdisjoint(pharmacy_stock)
print(has_all_core_drugs)
# 3. Is there any overlap between `pharmacy_stock` and `banned_drugs`?
has_overlap = not pharmacy_stock.isdisjoint(banned_drugs)
print(has_overlap)
# Out:
# True
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 10
#       6 # 1. Does the pharmacy have all the core drugs in stock?
#       7 has_all_core_drugs = core_drugs.issubset(pharmacy_stock)
#       8 print(has_all_core_drugs)
#       9 # 2. Does the pharmacy's stock fully contain the core drug list?
# ---> 10 has_all_core_drugs = core_drugs.isdisjoint(pharmcy_stock)
#      11 print(has_all_core_drugs)
#      12 # 3. Is there any overlap between `pharmacy_stock` and `banned_drugs`?
#
# NameError: name 'pharmcy_stock' is not defined

# %% [markdown]
# ### Q9 - Set comprehension `[3 marks]`
#
# ```python
# product_prices = {"Laptop": 85000, "Mouse": 1200, "Keyboard": 2500,
#                   "Monitor": 32000, "Webcam": 4500, "Headset": 6800,
#                   "USB Hub": 1800, "Desk Lamp": 950, "Mousepad": 450}
# ```
#
# Using **set comprehensions**:
# 1. Build a set of all product names that cost **more than 5000**
# 2. Build a set of the **first letter** of every product name
#    (this shows the alphabet coverage of your catalog)
# 3. Build a set of all price values that are **divisible by 1000**
#    (these are round-number prices)
#
# Print all three sets.

# %%
product_prices = {"Laptop": 85000, "Mouse": 1200, "Keyboard": 2500,
                  "Monitor": 32000, "Webcam": 4500, "Headset": 6800,
                  "USB Hub": 1800, "Desk Lamp": 950, "Mousepad": 450}

# 1. expensive items set
expensive_items = {item for item,price in product_prices.items() if price > 5000}
print(expensive_items)
# 2. first letters set
first_letters ={item[0] for item in product_prices.keys()}
print(first_letters)
# 3. round prices set
round_prices = {round(price) for price in product_prices.values()}
print(round_prices)
# Out:
# {'Headset', 'Laptop', 'Monitor'}
# {'U', 'D', 'M', 'L', 'K', 'W', 'H'}
# {32000, 450, 2500, 85000, 1800, 1200, 6800, 4500, 950}

# %% [markdown]
# ### Q10 - Combine dicts and sets `[3 marks]`
#
# This question requires you to use both structures together.
#
# ```python
# team_a_skills = {"Ahmad": {"Python", "SQL", "Excel"},
#                  "Sara":  {"Python", "R", "Tableau"},
#                  "Bilal": {"Java", "SQL", "Power BI"}}
#
# team_b_skills = {"Zara":   {"Python", "SQL", "Spark"},
#                  "Hassan": {"Python", "Machine Learning", "SQL"},
#                  "Nida":   {"R", "Tableau", "Excel"}}
# ```
#
# 1. Build `all_team_a_skills`: the **union** of all skill sets in team A
#    (combine every person's skills into one big set)
# 2. Build `all_team_b_skills`: the same for team B
# 3. Print the skills that **appear in both teams** (intersection)
# 4. Print skills that **only team A** has
# 5. Print skills that **only team B** has
# 6. Build a dict `skill_count` that maps each unique skill (across both teams)
#    to the total number of people (across both teams) who have it.
#    Use a dict comprehension.
#
# *Hint for 1: use a for loop or nested comprehension to union all sets together.*

# %%
team_a_skills = {"Ahmad": {"Python", "SQL", "Excel"},
                 "Sara":  {"Python", "R", "Tableau"},
                 "Bilal": {"Java", "SQL", "Power BI"}}

team_b_skills = {"Zara":   {"Python", "SQL", "Spark"},
                 "Hassan": {"Python", "Machine Learning", "SQL"},
                 "Nida":   {"R", "Tableau", "Excel"}}

# 1. all team A skills
skills_a = set().union(*team_a_skills.values())
print(skills_a)
# 2. all team B skills
skills_b = set().union(*team_b_skills.values())
print(skills_b)

# 3. shared skills
shared_skills = skills_a&skills_b
print(shared_skills)
# 4. only team A
only_team_a = skills_a - skills_b
print(only_team_a)
# 5. only team B
only_team_b = skills_b - skills_a
print(only_team_b)
# 6. skill_count dict
skill_count = {skill: (sum(skill in skills for skills in team_a_skills.values()) +
                         sum(skill in skills for skills in team_b_skills.values()))
               for skill in skills_a | skills_b}
print(skill_count)
# Out:
# {'Python', 'Power BI', 'Java', 'R', 'SQL', 'Tableau', 'Excel'}
# {'Python', 'Tableau', 'R', 'Machine Learning', 'SQL', 'Spark', 'Excel'}
# {'Python', 'R', 'Excel', 'SQL', 'Tableau'}
# {'Power BI', 'Java'}
# {'Machine Learning', 'Spark'}
# {'Python': 4, 'R': 2, 'Spark': 1, 'Excel': 2, 'Power BI': 1, 'Java': 1, 'Machine Learning': 1, 'SQL': 4, 'Tableau': 2}

# %% [markdown]
# ## Dataset 1 - ShopPK E-Commerce Product Catalog
#
# *Do not modify this cell.*
#
# This is the product catalog database for **ShopPK**, a Pakistani e-commerce platform.
# It mirrors the JSON structure returned by a real product API (Shopify, WooCommerce,
# or a custom REST endpoint). Each SKU (Stock Keeping Unit) maps to a nested dictionary with four sections:
# `info`, `pricing`, `inventory`, and `ratings`.
#
# Run this cell before attempting Q11-Q20.

# %%
# ShopPK Product Catalog - do not modify
product_catalog = {
    "SKU-001": {
        "info": {
            "name": "Logitech MX Master 3 Wireless Mouse",
            "brand": "Logitech",
            "category": "Electronics",
            "subcategory": "Computer Peripherals",
            "tags": ["wireless", "ergonomic", "office"]
        },
        "pricing": {
            "cost_price": 8500,
            "sale_price": 12999,
            "discount_pct": 0,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 42,
            "warehouse": "KHI-01",
            "reorder_level": 10,
            "last_restocked": "2024-01-10"
        },
        "ratings": {
            "avg_score": 4.7,
            "total_reviews": 234,
            "five_star": 158,
            "one_star": 8
        }
    },
    "SKU-002": {
        "info": {
            "name": "Samsung 27-inch FHD Monitor",
            "brand": "Samsung",
            "category": "Electronics",
            "subcategory": "Displays",
            "tags": ["monitor", "FHD", "IPS"]
        },
        "pricing": {
            "cost_price": 28000,
            "sale_price": 38500,
            "discount_pct": 10,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 8,
            "warehouse": "LHR-02",
            "reorder_level": 5,
            "last_restocked": "2024-01-05"
        },
        "ratings": {
            "avg_score": 4.4,
            "total_reviews": 89,
            "five_star": 54,
            "one_star": 5
        }
    },
    "SKU-003": {
        "info": {
            "name": "Canon PIXMA G3010 Ink Tank Printer",
            "brand": "Canon",
            "category": "Electronics",
            "subcategory": "Printers",
            "tags": ["printer", "ink-tank", "wireless"]
        },
        "pricing": {
            "cost_price": 22000,
            "sale_price": 29999,
            "discount_pct": 5,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 3,
            "warehouse": "ISB-03",
            "reorder_level": 5,
            "last_restocked": "2023-12-20"
        },
        "ratings": {
            "avg_score": 4.1,
            "total_reviews": 156,
            "five_star": 87,
            "one_star": 22
        }
    },
    "SKU-004": {
        "info": {
            "name": "Sapphire Premium Lawn Suit (3-piece)",
            "brand": "Sapphire",
            "category": "Fashion",
            "subcategory": "Women Clothing",
            "tags": ["lawn", "summer", "unstitched"]
        },
        "pricing": {
            "cost_price": 2800,
            "sale_price": 4500,
            "discount_pct": 15,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 120,
            "warehouse": "LHR-02",
            "reorder_level": 25,
            "last_restocked": "2024-01-12"
        },
        "ratings": {
            "avg_score": 4.8,
            "total_reviews": 512,
            "five_star": 430,
            "one_star": 12
        }
    },
    "SKU-005": {
        "info": {
            "name": "Haier 1.5 Ton Split AC (HSU-18HFC)",
            "brand": "Haier",
            "category": "Home Appliances",
            "subcategory": "Air Conditioners",
            "tags": ["AC", "1.5-ton", "energy-saving"]
        },
        "pricing": {
            "cost_price": 68000,
            "sale_price": 89999,
            "discount_pct": 0,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 15,
            "warehouse": "KHI-01",
            "reorder_level": 5,
            "last_restocked": "2024-01-08"
        },
        "ratings": {
            "avg_score": 4.3,
            "total_reviews": 341,
            "five_star": 210,
            "one_star": 28
        }
    },
    "SKU-006": {
        "info": {
            "name": "National Foods Biryani Masala (6-pack)",
            "brand": "National Foods",
            "category": "Groceries",
            "subcategory": "Spices & Masalas",
            "tags": ["masala", "biryani", "pack"]
        },
        "pricing": {
            "cost_price": 350,
            "sale_price": 540,
            "discount_pct": 0,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 280,
            "warehouse": "KHI-01",
            "reorder_level": 50,
            "last_restocked": "2024-01-14"
        },
        "ratings": {
            "avg_score": 4.6,
            "total_reviews": 1023,
            "five_star": 780,
            "one_star": 31
        }
    },
    "SKU-007": {
        "info": {
            "name": "Dawlance 12 CFT Refrigerator (DW-300 LBF)",
            "brand": "Dawlance",
            "category": "Home Appliances",
            "subcategory": "Refrigerators",
            "tags": ["fridge", "12-cft", "inverter"]
        },
        "pricing": {
            "cost_price": 52000,
            "sale_price": 72999,
            "discount_pct": 8,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 9,
            "warehouse": "LHR-02",
            "reorder_level": 5,
            "last_restocked": "2024-01-03"
        },
        "ratings": {
            "avg_score": 4.5,
            "total_reviews": 278,
            "five_star": 191,
            "one_star": 14
        }
    }
}

print(f"Catalog loaded: {len(product_catalog)} products")
print("SKUs:", list(product_catalog.keys()))
# Out:
# Catalog loaded: 7 products
# SKUs: ['SKU-001', 'SKU-002', 'SKU-003', 'SKU-004', 'SKU-005', 'SKU-006', 'SKU-007']

# %% [markdown]
# ## Phase 2 - E-Commerce Catalog Analysis `[30 marks | 3 marks each]`
#
# All questions in this phase use `product_catalog` defined above.
# Think of yourself as a data analyst at ShopPK - these are real
# questions a business would ask about its product database.

# %% [markdown]
# ### Q11 - Nested access and safe lookup `[3 marks]`
#
# 1. Print the **name**, **sale price**, and **avg rating** of `SKU-004`
#    by chaining dictionary keys (e.g. `d["..."]["..."]["..."]`)
#
# 2. Safely retrieve the `"color"` field from `SKU-001`'s
#    `"info"` section. Since that key does not exist, your `program` should
#    return the string `"color not specified"` instead of crashing.
#
# 3. Print the warehouse location for `SKU-003` and `SKU-006` in one f-string
#    each.
#
# *Nested .get() chain: `d.get("...", {}).get("...", {}).get("...", "....")`*

# %%
# ShopPK Product Catalog - do not modify
product_catalog = {
    "SKU-001": {
        "info": {
            "name": "Logitech MX Master 3 Wireless Mouse",
            "brand": "Logitech",
            "category": "Electronics",
            "subcategory": "Computer Peripherals",
            "tags": ["wireless", "ergonomic", "office"]
        },
        "pricing": {
            "cost_price": 8500,
            "sale_price": 12999,
            "discount_pct": 0,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 42,
            "warehouse": "KHI-01",
            "reorder_level": 10,
            "last_restocked": "2024-01-10"
        },
        "ratings": {
            "avg_score": 4.7,
            "total_reviews": 234,
            "five_star": 158,
            "one_star": 8
        }
    },
    "SKU-002": {
        "info": {
            "name": "Samsung 27-inch FHD Monitor",
            "brand": "Samsung",
            "category": "Electronics",
            "subcategory": "Displays",
            "tags": ["monitor", "FHD", "IPS"]
        },
        "pricing": {
            "cost_price": 28000,
            "sale_price": 38500,
            "discount_pct": 10,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 8,
            "warehouse": "LHR-02",
            "reorder_level": 5,
            "last_restocked": "2024-01-05"
        },
        "ratings": {
            "avg_score": 4.4,
            "total_reviews": 89,
            "five_star": 54,
            "one_star": 5
        }
    },
    "SKU-003": {
        "info": {
            "name": "Canon PIXMA G3010 Ink Tank Printer",
            "brand": "Canon",
            "category": "Electronics",
            "subcategory": "Printers",
            "tags": ["printer", "ink-tank", "wireless"]
        },
        "pricing": {
            "cost_price": 22000,
            "sale_price": 29999,
            "discount_pct": 5,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 3,
            "warehouse": "ISB-03",
            "reorder_level": 5,
            "last_restocked": "2023-12-20"
        },
        "ratings": {
            "avg_score": 4.1,
            "total_reviews": 156,
            "five_star": 87,
            "one_star": 22
        }
    },
    "SKU-004": {
        "info": {
            "name": "Sapphire Premium Lawn Suit (3-piece)",
            "brand": "Sapphire",
            "category": "Fashion",
            "subcategory": "Women Clothing",
            "tags": ["lawn", "summer", "unstitched"]
        },
        "pricing": {
            "cost_price": 2800,
            "sale_price": 4500,
            "discount_pct": 15,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 120,
            "warehouse": "LHR-02",
            "reorder_level": 25,
            "last_restocked": "2024-01-12"
        },
        "ratings": {
            "avg_score": 4.8,
            "total_reviews": 512,
            "five_star": 430,
            "one_star": 12
        }
    },
    "SKU-005": {
        "info": {
            "name": "Haier 1.5 Ton Split AC (HSU-18HFC)",
            "brand": "Haier",
            "category": "Home Appliances",
            "subcategory": "Air Conditioners",
            "tags": ["AC", "1.5-ton", "energy-saving"]
        },
        "pricing": {
            "cost_price": 68000,
            "sale_price": 89999,
            "discount_pct": 0,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 15,
            "warehouse": "KHI-01",
            "reorder_level": 5,
            "last_restocked": "2024-01-08"
        },
        "ratings": {
            "avg_score": 4.3,
            "total_reviews": 341,
            "five_star": 210,
            "one_star": 28
        }
    },
    "SKU-006": {
        "info": {
            "name": "National Foods Biryani Masala (6-pack)",
            "brand": "National Foods",
            "category": "Groceries",
            "subcategory": "Spices & Masalas",
            "tags": ["masala", "biryani", "pack"]
        },
        "pricing": {
            "cost_price": 350,
            "sale_price": 540,
            "discount_pct": 0,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 280,
            "warehouse": "KHI-01",
            "reorder_level": 50,
            "last_restocked": "2024-01-14"
        },
        "ratings": {
            "avg_score": 4.6,
            "total_reviews": 1023,
            "five_star": 780,
            "one_star": 31
        }
    },
    "SKU-007": {
        "info": {
            "name": "Dawlance 12 CFT Refrigerator (DW-300 LBF)",
            "brand": "Dawlance",
            "category": "Home Appliances",
            "subcategory": "Refrigerators",
            "tags": ["fridge", "12-cft", "inverter"]
        },
        "pricing": {
            "cost_price": 52000,
            "sale_price": 72999,
            "discount_pct": 8,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 9,
            "warehouse": "LHR-02",
            "reorder_level": 5,
            "last_restocked": "2024-01-03"
        },
        "ratings": {
            "avg_score": 4.5,
            "total_reviews": 278,
            "five_star": 191,
            "one_star": 14
        }
    }
}

print(f"Catalog loaded: {len(product_catalog)} products")
print("SKUs:", list(product_catalog.keys()))

# 1. SKU-004 details
name = product_catalog["SKU-004"]["info"]["name"]
sale_price = product_catalog["SKU-004"]["pricing"]["sale_price"]
avg_rating = product_catalog["SKU-004"]["ratings"]["avg_score"]

print(f"Name: {name} | Sale Price: {sale_price} | Avg Rating: {avg_rating}")

# 2. Safe lookup for missing key
color = product_catalog.get("SKU-001", {}).get("info", {}).get("color", "color not specified")
print(f"Color: {color}")

# 3. Warehouse locations
print(f'SKU-003 warehouse: {product_catalog.get("SKU-003", {}).get("inventory", {}).get("warehouse", "Not Found")}')
print(f'SKU-006 warehouse: {product_catalog.get("SKU-006", {}).get("inventory", {}).get("warehouse", "Not Found")}')
# Out:
# Catalog loaded: 7 products
# SKUs: ['SKU-001', 'SKU-002', 'SKU-003', 'SKU-004', 'SKU-005', 'SKU-006', 'SKU-007']
# Name: Sapphire Premium Lawn Suit (3-piece) | Sale Price: 4500 | Avg Rating: 4.8
# Color: color not specified
# SKU-003 warehouse: ISB-03
# SKU-006 warehouse: KHI-01

# %%
# 1. SKU-004 details
 product_catalog=d["SKU-004"]["info"]["name"]
sale_price = product_catalog["SKU-004"]["pricing"]["sale_price"]
avg_rating = product_catalog["SKU-004"]["ratings"]["avg_score"]
print(f"name: {name}| Sale Price: {sale_price}| Avg Rating: {avg_rating}")
# 2. Safe lookup for missing key
colour = product_catalog.get("SKU-004", {}).get("info", {}).get("colour", "colour not found")
print(f"Colour: {colour}")


# 3. Warehouse for SKU-003 and SKU-006
print("SKU-003 warehouse:", product_catalog.get("SKU_003", {}).get("inventory", {}).get("warehouse", "Not Found"))
print("SKU-006 warehouse:", product_catalog.get("SKU_006", {}).get("inventory", {}).get("warehouse", "Not Found"))
# Out:
#   Cell In[59], line 2
#     product_catalog=d["SKU-004"]["info"]["name"]
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ### Q12 - Modify nested values `[3 marks]`
#
# The pricing team has made three updates. Apply them to `product_catalog`:
#
# 1. `SKU-002`'s `discount_pct` should be updated from `10` to `20`
#    (a flash sale is running)
# 2. `SKU-003` has been restocked - update `in_stock` from `3` to `47`
#    and update `last_restocked` to `"2024-01-20"`
# 3. Add a new key `"is_featured"` with value `True` to `SKU-001`'s `"info"` section
#
# After all three updates, print the modified sections to confirm
# (just the relevant sub-dicts, not the full catalog).

# %%
# ShopPK Product Catalog - do not modify
product_catalog = {
    "SKU-001": {
        "info": {
            "name": "Logitech MX Master 3 Wireless Mouse",
            "brand": "Logitech",
            "category": "Electronics",
            "subcategory": "Computer Peripherals",
            "tags": ["wireless", "ergonomic", "office"]
        },
        "pricing": {
            "cost_price": 8500,
            "sale_price": 12999,
            "discount_pct": 0,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 42,
            "warehouse": "KHI-01",
            "reorder_level": 10,
            "last_restocked": "2024-01-10"
        },
        "ratings": {
            "avg_score": 4.7,
            "total_reviews": 234,
            "five_star": 158,
            "one_star": 8
        }
    },
    "SKU-002": {
        "info": {
            "name": "Samsung 27-inch FHD Monitor",
            "brand": "Samsung",
            "category": "Electronics",
            "subcategory": "Displays",
            "tags": ["monitor", "FHD", "IPS"]
        },
        "pricing": {
            "cost_price": 28000,
            "sale_price": 38500,
            "discount_pct": 10,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 8,
            "warehouse": "LHR-02",
            "reorder_level": 5,
            "last_restocked": "2024-01-05"
        },
        "ratings": {
            "avg_score": 4.4,
            "total_reviews": 89,
            "five_star": 54,
            "one_star": 5
        }
    },
    "SKU-003": {
        "info": {
            "name": "Canon PIXMA G3010 Ink Tank Printer",
            "brand": "Canon",
            "category": "Electronics",
            "subcategory": "Printers",
            "tags": ["printer", "ink-tank", "wireless"]
        },
        "pricing": {
            "cost_price": 22000,
            "sale_price": 29999,
            "discount_pct": 5,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 3,
            "warehouse": "ISB-03",
            "reorder_level": 5,
            "last_restocked": "2023-12-20"
        },
        "ratings": {
            "avg_score": 4.1,
            "total_reviews": 156,
            "five_star": 87,
            "one_star": 22
        }
    },
    "SKU-004": {
        "info": {
            "name": "Sapphire Premium Lawn Suit (3-piece)",
            "brand": "Sapphire",
            "category": "Fashion",
            "subcategory": "Women Clothing",
            "tags": ["lawn", "summer", "unstitched"]
        },
        "pricing": {
            "cost_price": 2800,
            "sale_price": 4500,
            "discount_pct": 15,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 120,
            "warehouse": "LHR-02",
            "reorder_level": 25,
            "last_restocked": "2024-01-12"
        },
        "ratings": {
            "avg_score": 4.8,
            "total_reviews": 512,
            "five_star": 430,
            "one_star": 12
        }
    },
    "SKU-005": {
        "info": {
            "name": "Haier 1.5 Ton Split AC (HSU-18HFC)",
            "brand": "Haier",
            "category": "Home Appliances",
            "subcategory": "Air Conditioners",
            "tags": ["AC", "1.5-ton", "energy-saving"]
        },
        "pricing": {
            "cost_price": 68000,
            "sale_price": 89999,
            "discount_pct": 0,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 15,
            "warehouse": "KHI-01",
            "reorder_level": 5,
            "last_restocked": "2024-01-08"
        },
        "ratings": {
            "avg_score": 4.3,
            "total_reviews": 341,
            "five_star": 210,
            "one_star": 28
        }
    },
    "SKU-006": {
        "info": {
            "name": "National Foods Biryani Masala (6-pack)",
            "brand": "National Foods",
            "category": "Groceries",
            "subcategory": "Spices & Masalas",
            "tags": ["masala", "biryani", "pack"]
        },
        "pricing": {
            "cost_price": 350,
            "sale_price": 540,
            "discount_pct": 0,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 280,
            "warehouse": "KHI-01",
            "reorder_level": 50,
            "last_restocked": "2024-01-14"
        },
        "ratings": {
            "avg_score": 4.6,
            "total_reviews": 1023,
            "five_star": 780,
            "one_star": 31
        }
    },
    "SKU-007": {
        "info": {
            "name": "Dawlance 12 CFT Refrigerator (DW-300 LBF)",
            "brand": "Dawlance",
            "category": "Home Appliances",
            "subcategory": "Refrigerators",
            "tags": ["fridge", "12-cft", "inverter"]
        },
        "pricing": {
            "cost_price": 52000,
            "sale_price": 72999,
            "discount_pct": 8,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 9,
            "warehouse": "LHR-02",
            "reorder_level": 5,
            "last_restocked": "2024-01-03"
        },
        "ratings": {
            "avg_score": 4.5,
            "total_reviews": 278,
            "five_star": 191,
            "one_star": 14
        }
    }
}

print(f"Catalog loaded: {len(product_catalog)} products")
print("SKUs:", list(product_catalog.keys()))





# 1. Update SKU-002 discount
product_catalog["SKU-002"]["pricing"]["discount_pct"] = 20

# 2. Update SKU-003 inventory
product_catalog["SKU-003"]["inventory"]["in_stock"] = 47
product_catalog["SKU-003"]["inventory"]["last_restocked"] = "2024-01-20"
# 3. Add is_featured to SKU-001
product_catalog["SKU-001"]["is_featured"] = True
# Verify all three changes
print("Updated SKU-002 discount:", product_catalog["SKU-002"]["pricing"]["discount_pct"])
print("Updated SKU-003 inventory:", product_catalog["SKU-003"]["inventory"])
print("SKU-001 featured status:", product_catalog["SKU-001"]["is_featured"])
# Out:
# Catalog loaded: 7 products
# SKUs: ['SKU-001', 'SKU-002', 'SKU-003', 'SKU-004', 'SKU-005', 'SKU-006', 'SKU-007']
# Updated SKU-002 discount: 20
# Updated SKU-003 inventory: {'in_stock': 47, 'warehouse': 'ISB-03', 'reorder_level': 5, 'last_restocked': '2024-01-20'}
# SKU-001 featured status: True

# %% [markdown]
# ### Q13 - Dict comprehension over nested data `[3 marks]`
#
# Using **dict comprehensions** on `product_catalog`:
#
# 1. Build `name_lookup`: maps each SKU to its product name
#    ```
#    {"SKU-001": "Logitech MX Master 3 ...", "SKU-002": "Samsung ...", ...}
#    ```
#
# 2. Build `effective_price`: maps each SKU to the price **after discount**.
#    Formula: `sale_price * (1 - discount_pct / 100)`
#    Round to the nearest whole number.
#
# 3. Build `profit_margin`: maps each SKU to its **gross margin percentage**.
#    Formula: `(sale_price - cost_price) / sale_price * 100`
#    Round to 1 decimal place.
#
# Print all three dicts with clear labels.

# %%
# ShopPK Product Catalog - do not modify
product_catalog = {
    "SKU-001": {
        "info": {
            "name": "Logitech MX Master 3 Wireless Mouse",
            "brand": "Logitech",
            "category": "Electronics",
            "subcategory": "Computer Peripherals",
            "tags": ["wireless", "ergonomic", "office"]
        },
        "pricing": {
            "cost_price": 8500,
            "sale_price": 12999,
            "discount_pct": 0,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 42,
            "warehouse": "KHI-01",
            "reorder_level": 10,
            "last_restocked": "2024-01-10"
        },
        "ratings": {
            "avg_score": 4.7,
            "total_reviews": 234,
            "five_star": 158,
            "one_star": 8
        }
    },
    "SKU-002": {
        "info": {
            "name": "Samsung 27-inch FHD Monitor",
            "brand": "Samsung",
            "category": "Electronics",
            "subcategory": "Displays",
            "tags": ["monitor", "FHD", "IPS"]
        },
        "pricing": {
            "cost_price": 28000,
            "sale_price": 38500,
            "discount_pct": 10,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 8,
            "warehouse": "LHR-02",
            "reorder_level": 5,
            "last_restocked": "2024-01-05"
        },
        "ratings": {
            "avg_score": 4.4,
            "total_reviews": 89,
            "five_star": 54,
            "one_star": 5
        }
    },
    "SKU-003": {
        "info": {
            "name": "Canon PIXMA G3010 Ink Tank Printer",
            "brand": "Canon",
            "category": "Electronics",
            "subcategory": "Printers",
            "tags": ["printer", "ink-tank", "wireless"]
        },
        "pricing": {
            "cost_price": 22000,
            "sale_price": 29999,
            "discount_pct": 5,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 3,
            "warehouse": "ISB-03",
            "reorder_level": 5,
            "last_restocked": "2023-12-20"
        },
        "ratings": {
            "avg_score": 4.1,
            "total_reviews": 156,
            "five_star": 87,
            "one_star": 22
        }
    },
    "SKU-004": {
        "info": {
            "name": "Sapphire Premium Lawn Suit (3-piece)",
            "brand": "Sapphire",
            "category": "Fashion",
            "subcategory": "Women Clothing",
            "tags": ["lawn", "summer", "unstitched"]
        },
        "pricing": {
            "cost_price": 2800,
            "sale_price": 4500,
            "discount_pct": 15,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 120,
            "warehouse": "LHR-02",
            "reorder_level": 25,
            "last_restocked": "2024-01-12"
        },
        "ratings": {
            "avg_score": 4.8,
            "total_reviews": 512,
            "five_star": 430,
            "one_star": 12
        }
    },
    "SKU-005": {
        "info": {
            "name": "Haier 1.5 Ton Split AC (HSU-18HFC)",
            "brand": "Haier",
            "category": "Home Appliances",
            "subcategory": "Air Conditioners",
            "tags": ["AC", "1.5-ton", "energy-saving"]
        },
        "pricing": {
            "cost_price": 68000,
            "sale_price": 89999,
            "discount_pct": 0,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 15,
            "warehouse": "KHI-01",
            "reorder_level": 5,
            "last_restocked": "2024-01-08"
        },
        "ratings": {
            "avg_score": 4.3,
            "total_reviews": 341,
            "five_star": 210,
            "one_star": 28
        }
    },
    "SKU-006": {
        "info": {
            "name": "National Foods Biryani Masala (6-pack)",
            "brand": "National Foods",
            "category": "Groceries",
            "subcategory": "Spices & Masalas",
            "tags": ["masala", "biryani", "pack"]
        },
        "pricing": {
            "cost_price": 350,
            "sale_price": 540,
            "discount_pct": 0,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 280,
            "warehouse": "KHI-01",
            "reorder_level": 50,
            "last_restocked": "2024-01-14"
        },
        "ratings": {
            "avg_score": 4.6,
            "total_reviews": 1023,
            "five_star": 780,
            "one_star": 31
        }
    },
    "SKU-007": {
        "info": {
            "name": "Dawlance 12 CFT Refrigerator (DW-300 LBF)",
            "brand": "Dawlance",
            "category": "Home Appliances",
            "subcategory": "Refrigerators",
            "tags": ["fridge", "12-cft", "inverter"]
        },
        "pricing": {
            "cost_price": 52000,
            "sale_price": 72999,
            "discount_pct": 8,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 9,
            "warehouse": "LHR-02",
            "reorder_level": 5,
            "last_restocked": "2024-01-03"
        },
        "ratings": {
            "avg_score": 4.5,
            "total_reviews": 278,
            "five_star": 191,
            "one_star": 14
        }
    }
}

print(f"Catalog loaded: {len(product_catalog)} products")
print("SKUs:", list(product_catalog.keys()))

# Q13 - Dict comprehensions on nested catalog
# 1. name_lookup
name_lookup = {sku:details["info"]["name"] for sku, details in product_catalog.items()}
# 2. effective_price (after discount)
effective_price = {sku:details["pricing"]["sale_price"] * (1 - details["pricing"]["discount_pct"] / 100) for sku, details in product_catalog.items()}
# 3. profit_margin
profit_margin = {sku:details["pricing"]["sale_price"] - details["pricing"]["cost_price"] for sku, details in product_catalog.items()}
# Out:
# Catalog loaded: 7 products
# SKUs: ['SKU-001', 'SKU-002', 'SKU-003', 'SKU-004', 'SKU-005', 'SKU-006', 'SKU-007']

# %% [markdown]
# ### Q14 - Filter by nested condition `[3 marks]`
#
# 1. Build `low_stock_skus`: a **list** of SKU codes where
#    `in_stock <= reorder_level`. These products need to be reordered urgently.
#    Print the list and the count.
#
# 2. Build `top_rated`: a **dict** of SKUs where `avg_score >= 4.5`,
#    mapping SKU to `{"name": ..., "score": ...}`.
#    Print it.
#
# 3. Build `on_discount`: a **list** of product names (not SKUs) where
#    `discount_pct > 0`. Print the list.
#
# *Use list and dict comprehensions where possible.*

# %%
# ShopPK Product Catalog - do not modify
product_catalog = {
    "SKU-001": {
        "info": {
            "name": "Logitech MX Master 3 Wireless Mouse",
            "brand": "Logitech",
            "category": "Electronics",
            "subcategory": "Computer Peripherals",
            "tags": ["wireless", "ergonomic", "office"]
        },
        "pricing": {
            "cost_price": 8500,
            "sale_price": 12999,
            "discount_pct": 0,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 42,
            "warehouse": "KHI-01",
            "reorder_level": 10,
            "last_restocked": "2024-01-10"
        },
        "ratings": {
            "avg_score": 4.7,
            "total_reviews": 234,
            "five_star": 158,
            "one_star": 8
        }
    },
    "SKU-002": {
        "info": {
            "name": "Samsung 27-inch FHD Monitor",
            "brand": "Samsung",
            "category": "Electronics",
            "subcategory": "Displays",
            "tags": ["monitor", "FHD", "IPS"]
        },
        "pricing": {
            "cost_price": 28000,
            "sale_price": 38500,
            "discount_pct": 10,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 8,
            "warehouse": "LHR-02",
            "reorder_level": 5,
            "last_restocked": "2024-01-05"
        },
        "ratings": {
            "avg_score": 4.4,
            "total_reviews": 89,
            "five_star": 54,
            "one_star": 5
        }
    },
    "SKU-003": {
        "info": {
            "name": "Canon PIXMA G3010 Ink Tank Printer",
            "brand": "Canon",
            "category": "Electronics",
            "subcategory": "Printers",
            "tags": ["printer", "ink-tank", "wireless"]
        },
        "pricing": {
            "cost_price": 22000,
            "sale_price": 29999,
            "discount_pct": 5,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 3,
            "warehouse": "ISB-03",
            "reorder_level": 5,
            "last_restocked": "2023-12-20"
        },
        "ratings": {
            "avg_score": 4.1,
            "total_reviews": 156,
            "five_star": 87,
            "one_star": 22
        }
    },
    "SKU-004": {
        "info": {
            "name": "Sapphire Premium Lawn Suit (3-piece)",
            "brand": "Sapphire",
            "category": "Fashion",
            "subcategory": "Women Clothing",
            "tags": ["lawn", "summer", "unstitched"]
        },
        "pricing": {
            "cost_price": 2800,
            "sale_price": 4500,
            "discount_pct": 15,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 120,
            "warehouse": "LHR-02",
            "reorder_level": 25,
            "last_restocked": "2024-01-12"
        },
        "ratings": {
            "avg_score": 4.8,
            "total_reviews": 512,
            "five_star": 430,
            "one_star": 12
        }
    },
    "SKU-005": {
        "info": {
            "name": "Haier 1.5 Ton Split AC (HSU-18HFC)",
            "brand": "Haier",
            "category": "Home Appliances",
            "subcategory": "Air Conditioners",
            "tags": ["AC", "1.5-ton", "energy-saving"]
        },
        "pricing": {
            "cost_price": 68000,
            "sale_price": 89999,
            "discount_pct": 0,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 15,
            "warehouse": "KHI-01",
            "reorder_level": 5,
            "last_restocked": "2024-01-08"
        },
        "ratings": {
            "avg_score": 4.3,
            "total_reviews": 341,
            "five_star": 210,
            "one_star": 28
        }
    },
    "SKU-006": {
        "info": {
            "name": "National Foods Biryani Masala (6-pack)",
            "brand": "National Foods",
            "category": "Groceries",
            "subcategory": "Spices & Masalas",
            "tags": ["masala", "biryani", "pack"]
        },
        "pricing": {
            "cost_price": 350,
            "sale_price": 540,
            "discount_pct": 0,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 280,
            "warehouse": "KHI-01",
            "reorder_level": 50,
            "last_restocked": "2024-01-14"
        },
        "ratings": {
            "avg_score": 4.6,
            "total_reviews": 1023,
            "five_star": 780,
            "one_star": 31
        }
    },
    "SKU-007": {
        "info": {
            "name": "Dawlance 12 CFT Refrigerator (DW-300 LBF)",
            "brand": "Dawlance",
            "category": "Home Appliances",
            "subcategory": "Refrigerators",
            "tags": ["fridge", "12-cft", "inverter"]
        },
        "pricing": {
            "cost_price": 52000,
            "sale_price": 72999,
            "discount_pct": 8,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 9,
            "warehouse": "LHR-02",
            "reorder_level": 5,
            "last_restocked": "2024-01-03"
        },
        "ratings": {
            "avg_score": 4.5,
            "total_reviews": 278,
            "five_star": 191,
            "one_star": 14
        }
    }
}

print(f"Catalog loaded: {len(product_catalog)} products")
print("SKUs:", list(product_catalog.keys()))

# 1. low_stock_skus
low_stock_
# 2. top_rated

# 3. on_discount (names only)

# %% [markdown]
# ### Q15 - Aggregate across the catalog `[3 marks]`
#
# 1. Find the **total stock value** across all products.
#    Formula for each SKU: `in_stock * cost_price`. Sum all of them.
#    Print as: `Total inventory value: PKR X,XXX,XXX`
#
# 2. Find the **average sale price** across all products. Round to 0 decimal places.
#
# 3. Find the **total number of reviews** across all products.
#
# 4. Find the product with the **most reviews** (highest `total_reviews`).
#    Print its name and review count.
#
# *Hint: use `max(product_catalog, key=lambda sku: ...)` for the last one.*

# %%
# ShopPK Product Catalog - do not modify
product_catalog = {
    "SKU-001": {
        "info": {
            "name": "Logitech MX Master 3 Wireless Mouse",
            "brand": "Logitech",
            "category": "Electronics",
            "subcategory": "Computer Peripherals",
            "tags": ["wireless", "ergonomic", "office"]
        },
        "pricing": {
            "cost_price": 8500,
            "sale_price": 12999,
            "discount_pct": 0,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 42,
            "warehouse": "KHI-01",
            "reorder_level": 10,
            "last_restocked": "2024-01-10"
        },
        "ratings": {
            "avg_score": 4.7,
            "total_reviews": 234,
            "five_star": 158,
            "one_star": 8
        }
    },
    "SKU-002": {
        "info": {
            "name": "Samsung 27-inch FHD Monitor",
            "brand": "Samsung",
            "category": "Electronics",
            "subcategory": "Displays",
            "tags": ["monitor", "FHD", "IPS"]
        },
        "pricing": {
            "cost_price": 28000,
            "sale_price": 38500,
            "discount_pct": 10,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 8,
            "warehouse": "LHR-02",
            "reorder_level": 5,
            "last_restocked": "2024-01-05"
        },
        "ratings": {
            "avg_score": 4.4,
            "total_reviews": 89,
            "five_star": 54,
            "one_star": 5
        }
    },
    "SKU-003": {
        "info": {
            "name": "Canon PIXMA G3010 Ink Tank Printer",
            "brand": "Canon",
            "category": "Electronics",
            "subcategory": "Printers",
            "tags": ["printer", "ink-tank", "wireless"]
        },
        "pricing": {
            "cost_price": 22000,
            "sale_price": 29999,
            "discount_pct": 5,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 3,
            "warehouse": "ISB-03",
            "reorder_level": 5,
            "last_restocked": "2023-12-20"
        },
        "ratings": {
            "avg_score": 4.1,
            "total_reviews": 156,
            "five_star": 87,
            "one_star": 22
        }
    },
    "SKU-004": {
        "info": {
            "name": "Sapphire Premium Lawn Suit (3-piece)",
            "brand": "Sapphire",
            "category": "Fashion",
            "subcategory": "Women Clothing",
            "tags": ["lawn", "summer", "unstitched"]
        },
        "pricing": {
            "cost_price": 2800,
            "sale_price": 4500,
            "discount_pct": 15,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 120,
            "warehouse": "LHR-02",
            "reorder_level": 25,
            "last_restocked": "2024-01-12"
        },
        "ratings": {
            "avg_score": 4.8,
            "total_reviews": 512,
            "five_star": 430,
            "one_star": 12
        }
    },
    "SKU-005": {
        "info": {
            "name": "Haier 1.5 Ton Split AC (HSU-18HFC)",
            "brand": "Haier",
            "category": "Home Appliances",
            "subcategory": "Air Conditioners",
            "tags": ["AC", "1.5-ton", "energy-saving"]
        },
        "pricing": {
            "cost_price": 68000,
            "sale_price": 89999,
            "discount_pct": 0,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 15,
            "warehouse": "KHI-01",
            "reorder_level": 5,
            "last_restocked": "2024-01-08"
        },
        "ratings": {
            "avg_score": 4.3,
            "total_reviews": 341,
            "five_star": 210,
            "one_star": 28
        }
    },
    "SKU-006": {
        "info": {
            "name": "National Foods Biryani Masala (6-pack)",
            "brand": "National Foods",
            "category": "Groceries",
            "subcategory": "Spices & Masalas",
            "tags": ["masala", "biryani", "pack"]
        },
        "pricing": {
            "cost_price": 350,
            "sale_price": 540,
            "discount_pct": 0,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 280,
            "warehouse": "KHI-01",
            "reorder_level": 50,
            "last_restocked": "2024-01-14"
        },
        "ratings": {
            "avg_score": 4.6,
            "total_reviews": 1023,
            "five_star": 780,
            "one_star": 31
        }
    },
    "SKU-007": {
        "info": {
            "name": "Dawlance 12 CFT Refrigerator (DW-300 LBF)",
            "brand": "Dawlance",
            "category": "Home Appliances",
            "subcategory": "Refrigerators",
            "tags": ["fridge", "12-cft", "inverter"]
        },
        "pricing": {
            "cost_price": 52000,
            "sale_price": 72999,
            "discount_pct": 8,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 9,
            "warehouse": "LHR-02",
            "reorder_level": 5,
            "last_restocked": "2024-01-03"
        },
        "ratings": {
            "avg_score": 4.5,
            "total_reviews": 278,
            "five_star": 191,
            "one_star": 14
        }
    }
}

print(f"Catalog loaded: {len(product_catalog)} products")
print("SKUs:", list(product_catalog.keys()))
# 1. Total stock value
total_stock_value = sum(details["pricing"]["sale_price"] * details["inventory"]["in_stock"] for details in product_catalog.values()) 
# 2. Average sale price
average_sale_price = total_stock_value / sum(details["inventory"]["in_stock"] for details in product_catalog.values()) if sum(details["inventory"]["in_stock"] for details in product_catalog.values()) > 0 else 0
# 3. Total reviews
total_reviews = sum(details["ratings"]["total_reviews"] for details in product_catalog.values())
# 4. Most reviewed product
most_reviewed_product = max(product_catalog.items(), key=lambda x: x[1]["ratings"]["total_reviews"])[0]
# Out:
# Catalog loaded: 7 products
# SKUs: ['SKU-001', 'SKU-002', 'SKU-003', 'SKU-004', 'SKU-005', 'SKU-006', 'SKU-007']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 203
#     199 average_sale_price = total_stock_value / sum(details["inventory"]["in_stock"] for details in product_catalog.values()) if sum(details["inventory"]["in_stock"] for details in product_catalog.values()) > 0 else 0
#     200 # 3. Total reviews
#     201 total_reviews = sum(details["ratings"]["total_reviews"] for details in product_catalog.values())
#     202 # 4. Most reviewed product
# --> 203 most_reviewed_product = max(product_catalog.items(), key=lambda x: x[1]["ratings"]["total_reviews"])[0]
#
# TypeError: 'int' object is not callable

# %% [markdown]
# ### Q16 - Sort and rank products `[3 marks]`
#
# 1. Sort all SKUs by **sale price** from **cheapest to most expensive**.
#    Print each SKU, product name, and price in a formatted table.
#
# 2. Sort all SKUs by **avg_score** from **highest to lowest**.
#    Print the top 3 as a "Best Rated Products" leaderboard.
#
# 3. Sort all SKUs by **in_stock** from **lowest to highest**
#    (most urgent restocking need first). Print as a restocking priority list.
#
# *Hint: `sorted(product_catalog, key=lambda sku: product_catalog[sku]["pricing"]["sale_price"])`*

# %%
# 1. Sort by sale price
sorted_by_price = sorted(product_catalog.items(),key = lambda x:x[1]["pricing"]["sale_price"],reverse = True)
# 2. Top 3 by rating
top_3_by_rating = sorted(product_catalog.items(),key = lambda x:x[1]["ratings"]["avg_score"],reverse = True)[:3]
# 3. Restocking priority
restocking_priority = sorted(product_catalog.items(),key = lambda x:x[1]["inventory"]["in_stock"])

# %% [markdown]
# ### Q17 - Build a category index using sets `[3 marks]`
#
# 1. Extract all unique **categories** present in the catalog into a set.
#    Print the set.
#
# 2. Extract all unique **subcategories** into a set. Print the set.
#
# 3. Build `category_skus`: a dict mapping each **category** to the
#    **set of SKUs** in that category.
#    ```python
#    {"Electronics": {"SKU-001", "SKU-002", "SKU-003"}, ...}
#    ```
#    Print the dict.
#
# 4. Using `category_skus`, find which categories have **more than 1 product**.
#    Print those categories and their SKU counts.

# %%
# ShopPK Product Catalog - do not modify
product_catalog = {
    "SKU-001": {
        "info": {
            "name": "Logitech MX Master 3 Wireless Mouse",
            "brand": "Logitech",
            "category": "Electronics",
            "subcategory": "Computer Peripherals",
            "tags": ["wireless", "ergonomic", "office"]
        },
        "pricing": {
            "cost_price": 8500,
            "sale_price": 12999,
            "discount_pct": 0,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 42,
            "warehouse": "KHI-01",
            "reorder_level": 10,
            "last_restocked": "2024-01-10"
        },
        "ratings": {
            "avg_score": 4.7,
            "total_reviews": 234,
            "five_star": 158,
            "one_star": 8
        }
    },
    "SKU-002": {
        "info": {
            "name": "Samsung 27-inch FHD Monitor",
            "brand": "Samsung",
            "category": "Electronics",
            "subcategory": "Displays",
            "tags": ["monitor", "FHD", "IPS"]
        },
        "pricing": {
            "cost_price": 28000,
            "sale_price": 38500,
            "discount_pct": 10,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 8,
            "warehouse": "LHR-02",
            "reorder_level": 5,
            "last_restocked": "2024-01-05"
        },
        "ratings": {
            "avg_score": 4.4,
            "total_reviews": 89,
            "five_star": 54,
            "one_star": 5
        }
    },
    "SKU-003": {
        "info": {
            "name": "Canon PIXMA G3010 Ink Tank Printer",
            "brand": "Canon",
            "category": "Electronics",
            "subcategory": "Printers",
            "tags": ["printer", "ink-tank", "wireless"]
        },
        "pricing": {
            "cost_price": 22000,
            "sale_price": 29999,
            "discount_pct": 5,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 3,
            "warehouse": "ISB-03",
            "reorder_level": 5,
            "last_restocked": "2023-12-20"
        },
        "ratings": {
            "avg_score": 4.1,
            "total_reviews": 156,
            "five_star": 87,
            "one_star": 22
        }
    },
    "SKU-004": {
        "info": {
            "name": "Sapphire Premium Lawn Suit (3-piece)",
            "brand": "Sapphire",
            "category": "Fashion",
            "subcategory": "Women Clothing",
            "tags": ["lawn", "summer", "unstitched"]
        },
        "pricing": {
            "cost_price": 2800,
            "sale_price": 4500,
            "discount_pct": 15,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 120,
            "warehouse": "LHR-02",
            "reorder_level": 25,
            "last_restocked": "2024-01-12"
        },
        "ratings": {
            "avg_score": 4.8,
            "total_reviews": 512,
            "five_star": 430,
            "one_star": 12
        }
    },
    "SKU-005": {
        "info": {
            "name": "Haier 1.5 Ton Split AC (HSU-18HFC)",
            "brand": "Haier",
            "category": "Home Appliances",
            "subcategory": "Air Conditioners",
            "tags": ["AC", "1.5-ton", "energy-saving"]
        },
        "pricing": {
            "cost_price": 68000,
            "sale_price": 89999,
            "discount_pct": 0,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 15,
            "warehouse": "KHI-01",
            "reorder_level": 5,
            "last_restocked": "2024-01-08"
        },
        "ratings": {
            "avg_score": 4.3,
            "total_reviews": 341,
            "five_star": 210,
            "one_star": 28
        }
    },
    "SKU-006": {
        "info": {
            "name": "National Foods Biryani Masala (6-pack)",
            "brand": "National Foods",
            "category": "Groceries",
            "subcategory": "Spices & Masalas",
            "tags": ["masala", "biryani", "pack"]
        },
        "pricing": {
            "cost_price": 350,
            "sale_price": 540,
            "discount_pct": 0,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 280,
            "warehouse": "KHI-01",
            "reorder_level": 50,
            "last_restocked": "2024-01-14"
        },
        "ratings": {
            "avg_score": 4.6,
            "total_reviews": 1023,
            "five_star": 780,
            "one_star": 31
        }
    },
    "SKU-007": {
        "info": {
            "name": "Dawlance 12 CFT Refrigerator (DW-300 LBF)",
            "brand": "Dawlance",
            "category": "Home Appliances",
            "subcategory": "Refrigerators",
            "tags": ["fridge", "12-cft", "inverter"]
        },
        "pricing": {
            "cost_price": 52000,
            "sale_price": 72999,
            "discount_pct": 8,
            "currency": "PKR"
        },
        "inventory": {
            "in_stock": 9,
            "warehouse": "LHR-02",
            "reorder_level": 5,
            "last_restocked": "2024-01-03"
        },
        "ratings": {
            "avg_score": 4.5,
            "total_reviews": 278,
            "five_star": 191,
            "one_star": 14
        }
    }
}

print(f"Catalog loaded: {len(product_catalog)} products")
print("SKUs:", list(product_catalog.keys()))

# 1. Unique categories
unique_categories = set(details["info"]["category"] for details in product_catalog.values())
# 2. Unique subcategories
unique_subcategories = set(details["info"]["subcategory"] for details in product_catalog.values())
# 3. category_skus dict
category_skus = 
# 4. Categories with more than 1 product
# Out:
# Catalog loaded: 7 products
# SKUs: ['SKU-001', 'SKU-002', 'SKU-003', 'SKU-004', 'SKU-005', 'SKU-006', 'SKU-007']

# %% [markdown]
# ### Q18 - Tag analysis using set operations `[3 marks]`
#
# Each product has a `"tags"` list inside `"info"`. Treat each product's tags
# as a **set**.
#
# 1. Build `tag_sets`: a dict mapping each SKU to a **set** of its tags.
#
# 2. Find all products that have **both** `"wireless"` AND `"office"` in their tags.
#    Print their names.
#
# 3. Find the **union of all tags** across the entire catalog (every tag that
#    appears at least once). Print the full tag universe.
#
# 4. Find tags that appear in **only one product** (exclusive tags).
#    For each such tag, print the tag and the product name it belongs to.

# %%
# 1. tag_sets dict
tag_sets dict = 
# 2. Products with 'wireless' AND 'office' tags

# 3. Union of all tags

# 4. Tags exclusive to exactly one product

# %% [markdown]
# ### Q19 - Inverted index: warehouse to SKUs `[3 marks]`
#
# The logistics team needs to know what is stored in each warehouse.
# Build an inverted index from the catalog.
#
# 1. Build `warehouse_skus`: a dict where each **warehouse code** maps to a
#    **list of SKUs** stored there. Do this with a regular for loop.
#    ```python
#    {"KHI-01": ["SKU-001", "SKU-005", "SKU-006"], "LHR-02": [...], ...}
#    ```
#
# 2. For each warehouse, print the warehouse code, the SKU list,
#    and the **total in-stock units** across all products in that warehouse.
#
# 3. Which warehouse holds the highest total stock value
#    (units x cost_price across all its SKUs)? Print the winner.

# %%
warehouse_skus = {}

# 1. Build the inverted index

# 2. Print per-warehouse summary

# 3. Highest stock value warehouse

# %% [markdown]
# ### Q20 - Add a new product and full catalog summary `[3 marks]`
#
# 1. Add this new product to `product_catalog`:
#
# ```python
# "SKU-008": {
#     "info": {
#         "name": "JBL Flip 6 Bluetooth Speaker",
#         "brand": "JBL",
#         "category": "Electronics",
#         "subcategory": "Audio",
#         "tags": ["bluetooth", "portable", "waterproof"]
#     },
#     "pricing": {"cost_price": 14000, "sale_price": 19999,
#                 "discount_pct": 0, "currency": "PKR"},
#     "inventory": {"in_stock": 30, "warehouse": "KHI-01",
#                   "reorder_level": 8, "last_restocked": "2024-01-18"},
#     "ratings": {"avg_score": 4.6, "total_reviews": 0,
#                 "five_star": 0, "one_star": 0}
# }
# ```
#
# 2. Verify the catalog now has 8 products.
#
# 3. Print a one-page catalog summary report using f-strings:
#    - Total products
#    - Unique categories (as a sorted list)
#    - Products needing restock (in_stock <= reorder_level)
#    - Most and least expensive product names and prices
#    - Highest and lowest rated products (among those with > 0 reviews)

# %%
# 1. Add SKU-008

# 2. Verify count

# 3. Summary report

# %% [markdown]
# ## Dataset 2 - UAF Student Information System
#
# *Do not modify this cell.*
#
# This is the student registry for the **Department of Computer Science, UAF**.
# It mirrors the kind of schema stored in a university Student Information System (SIS)
# or exported from an LMS like Moodle or Blackboard.
#
# Each student ID maps to a dictionary where the inner values are **lists**:
# enrolled courses, grades, attendance percentages, skills, and extracurricular
# activities. This is the nested-lists-inside-dicts structure.
#
# Run this cell before attempting Q21-Q30.

# %%
# UAF Student Information System - do not modify
student_registry = {
    "2023-CS-001": {
        "name": "Ahmad Raza",
        "gender": "M",
        "dept": "Computer Science",
        "semester": 5,
        "cgpa": 3.72,
        "enrolled_courses":   ["CS-301", "CS-302", "CS-303", "MATH-301", "ENG-201"],
        "completed_courses":  ["CS-101", "CS-102", "CS-201", "CS-202", "MATH-201"],
        "current_grades":     [88, 74, 91, 65, 78],
        "attendance_pct":     [92, 68, 95, 71, 88],
        "skills":             ["Python", "C++", "SQL", "Git", "Linux"],
        "clubs":              ["ACM Student Chapter", "Coding Club"]
    },
    "2023-CS-002": {
        "name": "Sara Khan",
        "gender": "F",
        "dept": "Computer Science",
        "semester": 5,
        "cgpa": 3.91,
        "enrolled_courses":   ["CS-301", "CS-303", "CS-305", "MATH-301", "STAT-201"],
        "completed_courses":  ["CS-101", "CS-102", "CS-201", "CS-202", "CS-204"],
        "current_grades":     [94, 88, 96, 82, 90],
        "attendance_pct":     [98, 95, 99, 91, 97],
        "skills":             ["Python", "R", "SQL", "Tableau", "Excel"],
        "clubs":              ["Data Science Society", "Girls in Tech"]
    },
    "2023-CS-003": {
        "name": "Bilal Ahmed",
        "gender": "M",
        "dept": "Computer Science",
        "semester": 5,
        "cgpa": 3.10,
        "enrolled_courses":   ["CS-301", "CS-302", "CS-304", "MATH-301", "ENG-201"],
        "completed_courses":  ["CS-101", "CS-102", "CS-201", "MATH-201"],
        "current_grades":     [71, 58, 79, 62, 55],
        "attendance_pct":     [78, 61, 82, 70, 65],
        "skills":             ["Java", "C++", "HTML", "CSS"],
        "clubs":              ["Coding Club"]
    },
    "2023-CS-004": {
        "name": "Zara Malik",
        "gender": "F",
        "dept": "Computer Science",
        "semester": 5,
        "cgpa": 3.55,
        "enrolled_courses":   ["CS-301", "CS-303", "CS-305", "STAT-201", "ENG-201"],
        "completed_courses":  ["CS-101", "CS-102", "CS-201", "CS-202", "MATH-201"],
        "current_grades":     [83, 79, 85, 88, 72],
        "attendance_pct":     [90, 88, 93, 95, 85],
        "skills":             ["Python", "R", "SPSS", "Excel", "Tableau"],
        "clubs":              ["Data Science Society", "Environmental Club"]
    },
    "2023-CS-005": {
        "name": "Hassan Ali",
        "gender": "M",
        "dept": "Computer Science",
        "semester": 5,
        "cgpa": 3.38,
        "enrolled_courses":   ["CS-302", "CS-304", "CS-305", "MATH-301", "ENG-201"],
        "completed_courses":  ["CS-101", "CS-102", "CS-201", "CS-202"],
        "current_grades":     [77, 82, 69, 74, 88],
        "attendance_pct":     [85, 90, 75, 82, 93],
        "skills":             ["Python", "JavaScript", "Node.js", "MongoDB", "SQL"],
        "clubs":              ["Entrepreneurship Club", "Coding Club"]
    },
    "2023-CS-006": {
        "name": "Nida Butt",
        "gender": "F",
        "dept": "Computer Science",
        "semester": 5,
        "cgpa": 3.88,
        "enrolled_courses":   ["CS-301", "CS-303", "CS-305", "STAT-201", "MATH-301"],
        "completed_courses":  ["CS-101", "CS-102", "CS-201", "CS-202", "CS-204"],
        "current_grades":     [92, 95, 89, 91, 87],
        "attendance_pct":     [97, 99, 94, 98, 96],
        "skills":             ["Python", "Machine Learning", "TensorFlow", "SQL", "R"],
        "clubs":              ["Data Science Society", "Girls in Tech", "Research Forum"]
    },
    "2023-CS-007": {
        "name": "Usman Sheikh",
        "gender": "M",
        "dept": "Computer Science",
        "semester": 5,
        "cgpa": 2.89,
        "enrolled_courses":   ["CS-301", "CS-302", "CS-304", "ENG-201"],
        "completed_courses":  ["CS-101", "CS-102", "CS-201"],
        "current_grades":     [62, 48, 71, 55],
        "attendance_pct":     [65, 52, 70, 58],
        "skills":             ["C++", "HTML", "CSS"],
        "clubs":              []
    },
    "2023-CS-008": {
        "name": "Rabia Shahid",
        "gender": "F",
        "dept": "Computer Science",
        "semester": 5,
        "cgpa": 3.65,
        "enrolled_courses":   ["CS-303", "CS-305", "MATH-301", "STAT-201", "ENG-201"],
        "completed_courses":  ["CS-101", "CS-102", "CS-201", "CS-202", "MATH-201"],
        "current_grades":     [86, 81, 90, 85, 78],
        "attendance_pct":     [91, 87, 95, 92, 84],
        "skills":             ["Python", "SQL", "Power BI", "Excel", "DAX"],
        "clubs":              ["Data Science Society", "Photography Club"]
    }
}

print(f"Registry loaded: {len(student_registry)} students")
for sid, data in student_registry.items():
    print(f"  {sid}: {data['name']}  |  CGPA: {data['cgpa']}")
# Out:
# Registry loaded: 8 students
#   2023-CS-001: Ahmad Raza  |  CGPA: 3.72
#   2023-CS-002: Sara Khan  |  CGPA: 3.91
#   2023-CS-003: Bilal Ahmed  |  CGPA: 3.1
#   2023-CS-004: Zara Malik  |  CGPA: 3.55
#   2023-CS-005: Hassan Ali  |  CGPA: 3.38
#   2023-CS-006: Nida Butt  |  CGPA: 3.88
#   2023-CS-007: Usman Sheikh  |  CGPA: 2.89
#   2023-CS-008: Rabia Shahid  |  CGPA: 3.65

# %% [markdown]
# ## Phase 3 - Student Registry Analysis `[30 marks | 3 marks each]`
#
# All questions in this phase use `student_registry` defined above.
# You are the academic analytics officer - these are real questions
# a university department would need answered.

# %% [markdown]
# ### Q21 - Access nested lists and specific elements `[3 marks]`
#
# 1. Print Sara Khan's full list of currently enrolled courses.
# 2. Print the **third course** in Ahmad Raza's `enrolled_courses` list
#    (index 2).
# 3. Print Nida Butt's **highest current grade** and her **lowest attendance
#    percentage**. Use `max()` and `min()` directly on the nested lists.
# 4. Print the number of completed courses for every student as a
#    formatted table: `Name : X completed courses`

# %%
# 1. Sara's enrolled courses

# 2. Ahmad's third enrolled course

# 3. Nida's highest grade and lowest attendance

# 4. Completed courses count per student

# %% [markdown]
# ### Q22 - Modify nested lists `[3 marks]`
#
# 1. Usman Sheikh has just enrolled in `"STAT-201"`. Add/append it to his
#    `enrolled_courses` list. Print his updated list.
#
# 2. Bilal Ahmed's grade for `CS-302` (which is at index 1 in his
#    `current_grades` list) has been corrected from `58` to `64` after
#    a re-evaluation. Update it by index. Print his updated grades.
#
# 3. Usman has completed `"CS-201"` this semester. Move it to his
#    `completed_courses` list (or add `"CS-203"` to it). Then
#     remove the first course from his `enrolled_courses` using
#     `.pop()` (he dropped it). Print both lists.

# %%
# 1. Add STAT-201 to Usman's enrolled courses

# 2. Correct Bilal's CS-302 grade

# 3. Update Usman's completed and enrolled lists

# %% [markdown]
# ### Q23 - Aggregate across nested lists `[3 marks]`
#
# 1. For each student, compute their **current average grade** (average of
#    `current_grades`). Print a table sorted from highest to lowest average.
#
# 2. For each student, compute their **average attendance percentage**.
#    Flag students whose average attendance is **below 75%** as "AT RISK".
#    Print all students with their attendance average and status.
#
# 3. Count the **total number of course-enrolments** across all students
#    (sum of all `enrolled_courses` list lengths).

# %%
# 1. Average grade per student, sorted

# 2. Average attendance, with AT RISK flag

# 3. Total course enrolments

# %% [markdown]
# ### Q24 - Filter students by nested list content `[3 marks]`
#
# 1. Find all students enrolled in **`"CS-301"`** (it's somewhere in their
#    `enrolled_courses` list). Print their names and student IDs.
#
# 2. Find all students who have **`"Python"`** in their `skills` list.
#    Print their names.
#
# 3. Find all students who have **at least one grade below 60** in their
#    `current_grades`. These students are at academic risk.
#    Print their names and the specific grade(s) below 60.
#
# *Hint: `"CS-301" in student["enrolled_courses"]` works for list membership.*

# %%
# 1. Students enrolled in CS-301

# 2. Students with Python skill

# 3. Students with any grade below 60

# %% [markdown]
# ### Q25 - Build a set of all unique values from nested lists `[3 marks]`
#
# 1. Build `all_skills`: a **set** of every skill that exists across all students.
#    (Hint: loop through students and union each student's skills set into a
#    running set.)
#
# 2. Build `all_clubs`: a **set** of every club that any student belongs to.
#
# 3. Build `all_courses_taken`: a **set** of every course code that appears
#    in any student's `enrolled_courses` OR `completed_courses`.
#
# Print all three sets and their sizes.

# %%
all_skills = set()
all_clubs  = set()
all_courses_taken = set()

# your code here

print(f"Total unique skills  : {len(all_skills)}")
print(f"Unique skills: {all_skills}")
print(f"\nTotal unique clubs   : {len(all_clubs)}")
print(f"Unique clubs: {all_clubs}")
print(f"\nTotal unique courses : {len(all_courses_taken)}")
print(f"Unique courses: {sorted(all_courses_taken)}")
# Out:
# Total unique skills  : 0
# Unique skills: set()
#
# Total unique clubs   : 0
# Unique clubs: set()
#
# Total unique courses : 0
# Unique courses: []

# %% [markdown]
# ### Q26 - Set operations on nested list data `[3 marks]`
#
# Using skills sets:
#
# 1. Find skills that **every single student** has (intersection of all skill sets).
#    Print the result - if empty, print `"No skill is common to all students"`.
#
# 2. Find skills that are held by **Sara Khan but not by Ahmad Raza**.
#    (i.e. skills Ahmad should learn from Sara.)
#
# 3. Find the skills that are **unique to Nida Butt** - skills she has that
#    no other student in the registry has.
#
# 4. Build `data_science_students`: the set of student names who have
#    **at least 2** of these data skills: `{"Python", "R", "SQL", "Machine Learning",
#    "Tableau", "Power BI"}`.

# %%
# 1. Skills common to ALL students

# 2. Sara's skills that Ahmad doesn't have

# 3. Skills unique to Nida

# 4. Students with at least 2 data skills

# %% [markdown]
# ### Q27 - Build an inverted index: course to students `[3 marks]`
#
# Build `course_roster`: a dict where each **course code** maps to a
# **list of student names** enrolled in that course.
#
# ```python
# {"CS-301": ["Ahmad Raza", "Sara Khan", "Bilal Ahmed", ...], "CS-302": [...], ...}
# ```
#
# 1. Build this using a for loop over all students and their `enrolled_courses`.
# 2. Print each course and its roster, sorted alphabetically by course code.
# 3. Find the course with the **most students** enrolled.
# 4. Find courses with **only one student** enrolled.

# %%
course_roster = {}

# 1. Build course_roster

# 2. Print sorted roster

# 3. Most popular course

# 4. Courses with only one student

# %% [markdown]
# ### Q28 - Club membership analysis `[3 marks]`
#
# 1. Build `club_members`: a dict mapping each **club name** to a
#    **list of student names** who are members.
#
# 2. Print each club and its member count, sorted from **largest to smallest**.
#
# 3. Find students who are members of **more than 1 club**. Print their names
#    and the number of clubs they belong to.
#
# 4. Find students with **no club memberships** at all (empty `clubs` list).
#    Print their names.
#
# 5. Which club has the most members? Print the club name and member list.

# %%
club_members = {}

# 1. Build club_members

# 2. Print sorted by size

# 3. Students in more than 1 club

# 4. Students with no clubs

# 5. Largest club

# %% [markdown]
# ### Q29 - Cross-reference: skills vs grades `[3 marks]`
#
# This question combines dicts, nested lists, and set operations.
#
# 1. Build `skill_to_students`: a dict mapping each skill to a list of
#    student names who have that skill (similar to the inverted index in Q27,
#    but for skills).
#
# 2. Find the **average grade** for students who know **Python** vs students
#    who do **not** know Python. Is there a difference?
#    (Average grade = mean of all values in `current_grades`.)
#
# 3. Build a dict `student_profile` for each student that contains:
#    - `"name"`: the student's name
#    - `"avg_grade"`: their average current grade (rounded to 1 dp)
#    - `"avg_attendance"`: their average attendance (rounded to 1 dp)
#    - `"skill_count"`: how many skills they have
#    - `"status"`: `"Excellent"` if avg_grade >= 85 and avg_attendance >= 90,
#      `"Good"` if avg_grade >= 70, else `"Needs Support"`
#
#    Print the profile for every student.

# %%
# 1. skill_to_students inverted index

# 2. Python vs non-Python average grade

# 3. student_profile dict

# %% [markdown]
# ### Q30 - Full Department Report `[3 marks]`
#
# Generate a comprehensive academic report for the department head.
# Use everything you have computed in Q21-Q29.
#
# Your report must include:
#
# 1. **Department Overview**
#    - Total students, male count, female count
#    - Highest CGPA student and lowest CGPA student
#
# 2. **Academic Performance**
#    - Class average of current grades (average all individual grades)
#    - Number of students with average grade >= 80 (Honours)
#    - Number of students at academic risk (any grade < 60)
#
# 3. **Attendance Summary**
#    - Students with average attendance >= 90% (Excellent)
#    - Students with average attendance < 75% (At Risk)
#
# 4. **Skills Landscape**
#    - Top 5 most common skills across the department
#    - Skills held by fewer than 3 students (rare skills)
#
# 5. **Course Load**
#    - Most popular currently enrolled course
#    - Student with the most total courses (enrolled + completed combined)
#
# Format the report using f-strings. Make it look like something you would
# actually submit to a department chair.

# %%
print("=" * 60)
print("DEPARTMENT OF COMPUTER SCIENCE - UAF")
print("SEMESTER 5 ACADEMIC REPORT")
print("=" * 60)

# 1. Department Overview

# 2. Academic Performance

# 3. Attendance Summary

# 4. Skills Landscape

# 5. Course Load
# Out:
# ...
# DEPARTMENT OF COMPUTER SCIENCE - UAF
# SEMESTER 5 ACADEMIC REPORT
# ...

# %% [markdown]
# ## Submission Checklist
#
# - [ ] All 30 questions have working code (no errors on Restart & Run All)
# - [ ] Phase 1 (Q1-Q10): used dict comprehensions and set operators where relevant
# - [ ] Phase 2 (Q11-Q20): accessed nested dict values using chained keys and `.get()`
# - [ ] Phase 3 (Q21-Q30): accessed nested lists by index and membership testing
# - [ ] Q30 report is formatted professionally using f-strings
#
# **Name:** ___________________________
#
# **Submission Date:** ___________________________
